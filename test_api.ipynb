# %% [markdown]
# # TEST OUT APIs for the Lambda function

# %%
import os
import urllib.request

event = {
    "queryStringParameters": {
        "token_type": "GITHUB",
        "url": "https://api.github.com/repos/ttoommxxDB/rosacimbra_website/contents/db"
    }
}

url = event['queryStringParameters']['url']
token_type = event['queryStringParameters']['token_type']

# %%
request = urllib.request.Request(url)
with urllib.request.urlopen(request) as response:
    data = response.read().decode()

# %%
data
# Out:
# '[{"name":"banner.txt","path":"db/banner.txt","sha":"3e6835fbcff65c54bef1357e07e441afcce3f901","size":112,"url":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/contents/db/banner.txt?ref=main","html_url":"https://github.com/ttoommxxDB/rosacimbra_website/blob/main/db/banner.txt","git_url":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/git/blobs/3e6835fbcff65c54bef1357e07e441afcce3f901","download_url":"https://raw.githubusercontent.com/ttoommxxDB/rosacimbra_website/main/db/banner.txt","type":"file","_links":{"self":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/contents/db/banner.txt?ref=main","git":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/git/blobs/3e6835fbcff65c54bef1357e07e441afcce3f901","html":"https://github.com/ttoommxxDB/rosacimbra_website/blob/main/db/banner.txt"}},{"name":"mydolls..doll_in_balcony.jpg","path":"db/mydolls..doll_in_balcony.jpg","sha":"95f66e56a8d4e877408634a2490d042b676b0bf5","size":163550,"url":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/contents/db/mydolls..doll_in_balcony.jpg?ref=main","html_url":"https://github.com/ttoommxxDB/rosacimbra_website/blob/main/db/mydolls..doll_in_balcony.jpg","git_url":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/git/blobs/95f66e56a8d4e877408634a2490d042b676b0bf5","download_url":"https://raw.githubusercontent.com/ttoommxxDB/rosacimbra_website/main/db/mydolls..doll_in_balcony.jpg","type":"file","_links":{"self":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/contents/db/mydolls..doll_in_balcony.jpg?ref=main","git":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/git/blobs/95f66e56a8d4e877408634a2490d042b676b0bf5","html":"https://github.com/ttoommxxDB/rosacimbra_website/blob/main/db/mydolls..doll_in_balcony.jpg"}},{"name":"mydolls..doll_in_balcony.txt","path":"db/mydolls..doll_in_balcony.txt","sha":"8903988397d8d5b0bd0374d6377d015be297d893","size":98,"url":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/contents/db/mydolls..doll_in_balcony.txt?ref=main","html_url":"https://github.com/ttoommxxDB/rosacimbra_website/blob/main/db/mydolls..doll_in_balcony.txt","git_url":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/git/blobs/8903988397d8d5b0bd0374d6377d015be297d893","download_url":"https://raw.githubusercontent.com/ttoommxxDB/rosacimbra_website/main/db/mydolls..doll_in_balcony.txt","type":"file","_links":{"self":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/contents/db/mydolls..doll_in_balcony.txt?ref=main","git":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/git/blobs/8903988397d8d5b0bd0374d6377d015be297d893","html":"https://github.com/ttoommxxDB/rosacimbra_website/blob/main/db/mydolls..doll_in_balcony.txt"}},{"name":"mydolls..doll_with_chair.jpg","path":"db/mydolls..doll_with_chair.jpg","sha":"fc0db55c588c72d28e4fc396811a4dd163a76c80","size":173253,"url":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/contents/db/mydolls..doll_with_chair.jpg?ref=main","html_url":"https://github.com/ttoommxxDB/rosacimbra_website/blob/main/db/mydolls..doll_with_chair.jpg","git_url":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/git/blobs/fc0db55c588c72d28e4fc396811a4dd163a76c80","download_url":"https://raw.githubusercontent.com/ttoommxxDB/rosacimbra_website/main/db/mydolls..doll_with_chair.jpg","type":"file","_links":{"self":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/contents/db/mydolls..doll_with_chair.jpg?ref=main","git":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/git/blobs/fc0db55c588c72d28e4fc396811a4dd163a76c80","html":"https://github.com/ttoommxxDB/rosacimbra_website/blob/main/db/mydolls..doll_with_chair.jpg"}},{"name":"mydolls..doll_with_chair.txt","path":"db/mydolls..doll_with_chair.txt","sha":"6405f3928637bd061cc6ff2203420c5965ef8f23","size":81,"url":"https://api.github.com/repos/ttoommxxDB/rosacimbra_website/contents/db/mydolls..doll_with_chair.txt?ref=main","html_url": ...
